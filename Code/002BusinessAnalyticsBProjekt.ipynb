# %% [markdown]
# # Willkommen
#
# Kommentare immer unter dem Code

# %%
# %pip install numpy
# %pip install pandas
# %pip install matplotlib.pylab
# %pip install seaborn
# %pip install statsmodels
# Out:
# Requirement already satisfied: numpy in c:\users\dave\appdata\local\programs\python\python39\lib\site-packages (1.23.5)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'c:\Users\Dave\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas in c:\users\dave\appdata\local\programs\python\python39\lib\site-packages (1.5.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dave\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dave\appdata\roaming\python\python39\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\dave\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in c:\users\dave\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'c:\Users\Dave\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotlib.pylab (from versions: none)
# ERROR: No matching distribution found for matplotlib.pylab
# WARNING: You are using pip version 21.2.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'c:\Users\Dave\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: seaborn in c:\users\dave\appdata\local\programs\python\python39\lib\site-packages (0.12.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\dave\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.5.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\dave\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\dave\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dave\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dave\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\dave\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dave\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dave\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dave\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dave\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dave\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dave\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.25->seaborn) (2022.6)
# Requirement already satisfied: six>=1.5 in c:\users\dave\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'c:\Users\Dave\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: statsmodels in c:\users\dave\appdata\local\programs\python\python39\lib\site-packages (0.13.5)
# Requirement already satisfied: numpy>=1.17 in c:\users\dave\appdata\local\programs\python\python39\lib\site-packages (from statsmodels) (1.23.5)
# Requirement already satisfied: packaging>=21.3 in c:\users\dave\appdata\roaming\python\python39\site-packages (from statsmodels) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\dave\appdata\local\programs\python\python39\lib\site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: scipy>=1.3 in c:\users\dave\appdata\local\programs\python\python39\lib\site-packages (from statsmodels) (1.9.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\dave\appdata\local\programs\python\python39\lib\site-packages (from statsmodels) (1.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\dave\appdata\roaming\python\python39\site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dave\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.25->statsmodels) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dave\appdata\roaming\python\python39\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in c:\users\dave\appdata\roaming\python\python39\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'c:\Users\Dave\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline
sns.set(rc={'figure.figsize':(10,10)})

# %% [markdown]
# # 1) Daten einlesen

# %%
df_cal = pd.read_csv('../Data/calendar.csv', sep=',')
df_cal.head()
# Out:
#          date  week_id event_name_1 event_type_1 event_name_2 event_type_2  \
# 0  2011-03-01    11105          NaN          NaN          NaN          NaN
# 1  2011-03-02    11105          NaN          NaN          NaN          NaN
# 2  2011-03-03    11105          NaN          NaN          NaN          NaN
# 3  2011-03-04    11105          NaN          NaN          NaN          NaN
# 4  2011-03-05    11106          NaN          NaN          NaN          NaN
#
#    snap
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
df_price = pd.read_csv('../Data/prices.csv', sep=',')
df_price.head()
# Out:
#    Unnamed: 0        item_id  week_id  price
# 0           0  HOBBIES_1_001    11325   9.58
# 1           1  HOBBIES_1_001    11326   9.58
# 2           2  HOBBIES_1_001    11327   8.26
# 3           3  HOBBIES_1_001    11328   8.26
# 4           4  HOBBIES_1_001    11329   8.26

# %%
df_sales = pd.read_csv('../Data/sales.csv', sep=',')
df_sales
# Out:
#                date        item_id    dept_id   cat_id  sales
# 0        2011-03-01  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 1        2011-03-01  HOBBIES_1_002  HOBBIES_1  HOBBIES      0
# 2        2011-03-01  HOBBIES_1_003  HOBBIES_1  HOBBIES      0
# 3        2011-03-01  HOBBIES_1_004  HOBBIES_1  HOBBIES      0
# 4        2011-03-01  HOBBIES_1_005  HOBBIES_1  HOBBIES      0
# ...             ...            ...        ...      ...    ...
# 5570518  2016-02-29    FOODS_3_823    FOODS_3    FOODS      2
# 5570519  2016-02-29    FOODS_3_824    FOODS_3    FOODS      0
# 5570520  2016-02-29    FOODS_3_825    FOODS_3    FOODS      0
# 5570521  2016-02-29    FOODS_3_826    FOODS_3    FOODS      1
# 5570522  2016-02-29    FOODS_3_827    FOODS_3    FOODS      1
#
# [5570523 rows x 5 columns]

# %% [markdown]
# 2) Datenexploration

# %% [markdown]
# ###Calendar

# %%
df_cal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1858 entries, 0 to 1857
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1858 non-null   object
#  1   week_id       1858 non-null   int64
#  2   event_name_1  151 non-null    object
#  3   event_type_1  151 non-null    object
#  4   event_name_2  4 non-null      object
#  5   event_type_2  4 non-null      object
#  6   snap          1858 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 101.7+ KB

# %%
df_cal.describe()
# Out:
#             week_id         snap
# count   1858.000000  1858.000000
# mean   11339.624327     0.328310
# std      146.305645     0.469725
# min    11105.000000     0.000000
# 25%    11219.000000     0.000000
# 50%    11334.000000     0.000000
# 75%    11447.000000     1.000000
# max    11609.000000     1.000000

# %%
df_cal['date']
# Out:
# 0       2011-03-01
# 1       2011-03-02
# 2       2011-03-03
# 3       2011-03-04
# 4       2011-03-05
#            ...
# 1853    2016-03-27
# 1854    2016-03-28
# 1855    2016-03-29
# 1856    2016-03-30
# 1857    2016-03-31
# Name: date, Length: 1858, dtype: object

# %%
df_cal['event_name_1'].unique()
# Out:
# array([nan, 'LentStart', 'LentWeek2', 'StPatricksDay', 'Purim End',
#        'OrthodoxEaster', 'Pesach End', 'Cinco De Mayo', "Mother's day",
#        'MemorialDay', 'NBAFinalsStart', 'NBAFinalsEnd', "Father's day",
#        'IndependenceDay', 'Ramadan starts', 'Eid al-Fitr', 'LaborDay',
#        'ColumbusDay', 'Halloween', 'EidAlAdha', 'VeteransDay',
#        'Thanksgiving', 'Christmas', 'Chanukah End', 'NewYear',
#        'OrthodoxChristmas', 'MartinLutherKingDay', 'SuperBowl',
#        'ValentinesDay', 'PresidentsDay', 'Easter'], dtype=object)

# %%
df_cal['event_name_1'].value_counts()
# Out:
# LentStart              6
# StPatricksDay          6
# Purim End              6
# LentWeek2              6
# Halloween              5
# PresidentsDay          5
# ValentinesDay          5
# SuperBowl              5
# MartinLutherKingDay    5
# OrthodoxChristmas      5
# NewYear                5
# Chanukah End           5
# Christmas              5
# Thanksgiving           5
# VeteransDay            5
# EidAlAdha              5
# LaborDay               5
# ColumbusDay            5
# Eid al-Fitr            5
# Ramadan starts         5
# IndependenceDay        5
# NBAFinalsEnd           5
# NBAFinalsStart         5
# MemorialDay            5
# Mother's day           5
# Pesach End             5
# Easter                 5
# Father's day           4
# Cinco De Mayo          4
# OrthodoxEaster         4
# Name: event_name_1, dtype: int64

# %%
df_cal['event_name_1'].value_counts().sum()
# Out:
# 151

# %% [markdown]
# Von 1858 Datensätzen finden 151 an einem Feiertag statt.

# %%
df_cal['event_name_2'].value_counts()
# Out:
# Easter            1
# Cinco De Mayo     1
# OrthodoxEaster    1
# Father's day      1
# Name: event_name_2, dtype: int64

# %% [markdown]
# Doppelter Feiertag findet nur 4 mal im Datensatz statt.

# %%
df_cal['event_name_2'].unique()
# Out:
# array([nan, 'Easter', 'Cinco De Mayo', 'OrthodoxEaster', "Father's day"],
#       dtype=object)

# %%
df_cal['event_type_1'].unique()
# Out:
# array([nan, 'Religious', 'Cultural', 'National', 'Sporting'], dtype=object)

# %%
df_cal['event_type_2'].unique()
# Out:
# array([nan, 'Cultural', 'Religious'], dtype=object)

# %%
df_cal[df_cal['event_name_1'] == 'Easter']
# Out:
#             date  week_id event_name_1 event_type_1    event_name_2  \
# 404   2012-04-08    11211       Easter     Cultural             NaN
# 761   2013-03-31    11310       Easter     Cultural             NaN
# 1146  2014-04-20    11412       Easter     Cultural  OrthodoxEaster
# 1496  2015-04-05    11510       Easter     Cultural             NaN
# 1853  2016-03-27    11609       Easter     Cultural             NaN
#
#      event_type_2  snap
# 404           NaN     1
# 761           NaN     0
# 1146    Religious     0
# 1496          NaN     1
# 1853          NaN     0

# %%
df_cal[df_cal['event_name_2'] == 'Easter']
# Out:
#           date  week_id    event_name_1 event_type_1 event_name_2  \
# 54  2011-04-24    11113  OrthodoxEaster    Religious       Easter
#
#    event_type_2  snap
# 54     Cultural     0

# %% [markdown]
# 2 Events wahrscheinlich falls 2 Feiertage am selben Tag stattfinden.

# %%
df_cal['snap'].value_counts()
# Out:
# 0    1248
# 1     610
# Name: snap, dtype: int64

# %%
snap_test = df_cal[(df_cal['week_id']>=11105)&(df_cal['week_id']<=11130)]

# %%
plt.plot(snap_test['week_id'],snap_test['snap'])
plt.title('SNAP!')
plt.xlabel("week_id")
plt.ylabel("snap")
plt.legend(loc='upper right')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Dauer des Snap Angebots ist immer unterschiedlich lang.

# %% [markdown]
# Differenzen zwischen Snap tagen anschauen.

# %% [markdown]
# ###Prices

# %%
df_price = df_price.drop(columns=['Unnamed: 0'])
df_price
# Out:
#               item_id  week_id  price
# 0       HOBBIES_1_001    11325   9.58
# 1       HOBBIES_1_001    11326   9.58
# 2       HOBBIES_1_001    11327   8.26
# 3       HOBBIES_1_001    11328   8.26
# 4       HOBBIES_1_001    11329   8.26
# ...               ...      ...    ...
# 656545    FOODS_3_827    11605   1.00
# 656546    FOODS_3_827    11606   1.00
# 656547    FOODS_3_827    11607   1.00
# 656548    FOODS_3_827    11608   1.00
# 656549    FOODS_3_827    11609   1.00
#
# [656550 rows x 3 columns]

# %%
df_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 656550 entries, 0 to 656549
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   item_id  656550 non-null  object
#  1   week_id  656550 non-null  int64
#  2   price    656550 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 15.0+ MB

# %% [markdown]
# Price = durchschnittlicher Verkaufspreis der jeweiligen Woche
#
# Keine Nan's

# %%
df_price['item_id'].value_counts()
# Out:
# HOUSEHOLD_2_429    266
# HOUSEHOLD_2_368    266
# HOUSEHOLD_2_384    266
# HOUSEHOLD_2_383    266
# FOODS_3_495        266
#                   ...
# FOODS_2_248         23
# FOODS_2_117         14
# FOODS_2_209         14
# FOODS_3_296         11
# FOODS_3_595          7
# Name: item_id, Length: 3049, dtype: int64

# %%
df_price['price'].describe()
# Out:
# count    656550.000000
# mean          4.412243
# std           3.395917
# min           0.010000
# 25%           2.220000
# 50%           3.470000
# 75%           5.770000
# max          30.980000
# Name: price, dtype: float64

# %%
df_price[['item_id','price']][df_price['price']>30].groupby(by='item_id').count()
# Out:
#                price
# item_id
# HOBBIES_1_060    110
# HOBBIES_1_225    109
# HOBBIES_1_361    109

# %% [markdown]
# Items mit einem Verkaufspreis in der jeweiligen Woche mit einem Preis >30

# %%
df_price['week_id'].value_counts()
# Out:
# 11608    3049
# 11609    3049
# 11607    3049
# 11606    3049
# 11605    3049
#          ...
# 11109    1509
# 11108    1490
# 11107    1471
# 11106    1445
# 11105    1413
# Name: week_id, Length: 266, dtype: int64

# %% [markdown]
# In unterschiedlichen Wochen

# %% [markdown]
# ###Sales

# %% [markdown]
# Sales = Abverkauf in Stück pro Produkt pro Tag (auch wenn das Produkt nicht verkauft wurde)

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570523 entries, 0 to 5570522
# Data columns (total 5 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   date     object
#  1   item_id  object
#  2   dept_id  object
#  3   cat_id   object
#  4   sales    int64
# dtypes: int64(1), object(4)
# memory usage: 212.5+ MB

# %%
df_sales[df_sales['sales'].isna()]
# Out:
# Empty DataFrame
# Columns: [date, item_id, dept_id, cat_id, sales]
# Index: []

# %%
df_sales['sales'].describe()
# Out:
# count    5.570523e+06
# mean     1.319099e+00
# std      4.069521e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.000000e+00
# max      6.480000e+02
# Name: sales, dtype: float64

# %%
df_sales[df_sales['sales']==0]
# Out:
#                date        item_id    dept_id   cat_id  sales
# 0        2011-03-01  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 1        2011-03-01  HOBBIES_1_002  HOBBIES_1  HOBBIES      0
# 2        2011-03-01  HOBBIES_1_003  HOBBIES_1  HOBBIES      0
# 3        2011-03-01  HOBBIES_1_004  HOBBIES_1  HOBBIES      0
# 4        2011-03-01  HOBBIES_1_005  HOBBIES_1  HOBBIES      0
# ...             ...            ...        ...      ...    ...
# 5570512  2016-02-29    FOODS_3_817    FOODS_3    FOODS      0
# 5570515  2016-02-29    FOODS_3_820    FOODS_3    FOODS      0
# 5570516  2016-02-29    FOODS_3_821    FOODS_3    FOODS      0
# 5570519  2016-02-29    FOODS_3_824    FOODS_3    FOODS      0
# 5570520  2016-02-29    FOODS_3_825    FOODS_3    FOODS      0
#
# [3568017 rows x 5 columns]

# %%
df_sales[df_sales['date']=='2011-03-01']
# Out:
#             date        item_id    dept_id   cat_id  sales
# 0     2011-03-01  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 1     2011-03-01  HOBBIES_1_002  HOBBIES_1  HOBBIES      0
# 2     2011-03-01  HOBBIES_1_003  HOBBIES_1  HOBBIES      0
# 3     2011-03-01  HOBBIES_1_004  HOBBIES_1  HOBBIES      0
# 4     2011-03-01  HOBBIES_1_005  HOBBIES_1  HOBBIES      0
# ...          ...            ...        ...      ...    ...
# 3044  2011-03-01    FOODS_3_823    FOODS_3    FOODS      0
# 3045  2011-03-01    FOODS_3_824    FOODS_3    FOODS      0
# 3046  2011-03-01    FOODS_3_825    FOODS_3    FOODS      0
# 3047  2011-03-01    FOODS_3_826    FOODS_3    FOODS      0
# 3048  2011-03-01    FOODS_3_827    FOODS_3    FOODS      0
#
# [3049 rows x 5 columns]

# %% [markdown]
# Alle 3049 Produkte haben für jedes Date eine Verkaufsanzahl.

# %%
df_sales.groupby(by='cat_id').sum().plot.bar()
# Out:
# C:\Users\Dave\AppData\Local\Temp\ipykernel_29508\474284637.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_sales.groupby(by='cat_id').sum().plot.bar()
# <AxesSubplot: xlabel='cat_id'>

# %% [markdown]
# ### Mergen der Datensätze
#
# Calendar und Sales über das Datum
# Price hinzufügen über die week_id

# %%
df_calsales = pd.merge(df_cal,df_sales,how='left',on='date')
df_calsales
# Out:
#                date  week_id event_name_1 event_type_1 event_name_2  \
# 0        2011-03-01    11105          NaN          NaN          NaN
# 1        2011-03-01    11105          NaN          NaN          NaN
# 2        2011-03-01    11105          NaN          NaN          NaN
# 3        2011-03-01    11105          NaN          NaN          NaN
# 4        2011-03-01    11105          NaN          NaN          NaN
# ...             ...      ...          ...          ...          ...
# 5570549  2016-03-27    11609       Easter     Cultural          NaN
# 5570550  2016-03-28    11609          NaN          NaN          NaN
# 5570551  2016-03-29    11609          NaN          NaN          NaN
# 5570552  2016-03-30    11609          NaN          NaN          NaN
# 5570553  2016-03-31    11609          NaN          NaN          NaN
#
#         event_type_2  snap        item_id    dept_id   cat_id  sales
# 0                NaN     1  HOBBIES_1_001  HOBBIES_1  HOBBIES    0.0
# 1                NaN     1  HOBBIES_1_002  HOBBIES_1  HOBBIES    0.0
# 2                NaN     1  HOBBIES_1_003  HOBBIES_1  HOBBIES    0.0
# 3                NaN     1  HOBBIES_1_004  HOBBIES_1  HOBBIES    0.0
# 4                NaN     1  HOBBIES_1_005  HOBBIES_1  HOBBIES    0.0
# ...              ...   ...            ...        ...      ...    ...
# 5570549          NaN     0            NaN        NaN      NaN    NaN
# 5570550          NaN     0            NaN        NaN      NaN    NaN
# 5570551          NaN     0            NaN        NaN      NaN    NaN
# 5570552          NaN     0            NaN        NaN      NaN    NaN
# 5570553          NaN     0            NaN        NaN      NaN    NaN
#
# [5570554 rows x 11 columns]

# %%
df_calsales_past = df_calsales[df_calsales['date']<'2016-03-01']
df_calsales_past
# Out:
#                date  week_id event_name_1 event_type_1 event_name_2  \
# 0        2011-03-01    11105          NaN          NaN          NaN
# 1        2011-03-01    11105          NaN          NaN          NaN
# 2        2011-03-01    11105          NaN          NaN          NaN
# 3        2011-03-01    11105          NaN          NaN          NaN
# 4        2011-03-01    11105          NaN          NaN          NaN
# ...             ...      ...          ...          ...          ...
# 5570518  2016-02-29    11605          NaN          NaN          NaN
# 5570519  2016-02-29    11605          NaN          NaN          NaN
# 5570520  2016-02-29    11605          NaN          NaN          NaN
# 5570521  2016-02-29    11605          NaN          NaN          NaN
# 5570522  2016-02-29    11605          NaN          NaN          NaN
#
#         event_type_2  snap        item_id    dept_id   cat_id  sales
# 0                NaN     1  HOBBIES_1_001  HOBBIES_1  HOBBIES    0.0
# 1                NaN     1  HOBBIES_1_002  HOBBIES_1  HOBBIES    0.0
# 2                NaN     1  HOBBIES_1_003  HOBBIES_1  HOBBIES    0.0
# 3                NaN     1  HOBBIES_1_004  HOBBIES_1  HOBBIES    0.0
# 4                NaN     1  HOBBIES_1_005  HOBBIES_1  HOBBIES    0.0
# ...              ...   ...            ...        ...      ...    ...
# 5570518          NaN     0    FOODS_3_823    FOODS_3    FOODS    2.0
# 5570519          NaN     0    FOODS_3_824    FOODS_3    FOODS    0.0
# 5570520          NaN     0    FOODS_3_825    FOODS_3    FOODS    0.0
# 5570521          NaN     0    FOODS_3_826    FOODS_3    FOODS    1.0
# 5570522          NaN     0    FOODS_3_827    FOODS_3    FOODS    1.0
#
# [5570523 rows x 11 columns]

# %%
df_calsales_future = df_calsales[df_calsales['date']>='2016-03-01']
df_calsales_future = df_calsales_future.drop(columns = ['item_id','dept_id','cat_id'])
df_calsales_future
# Out:
#                date  week_id   event_name_1 event_type_1 event_name_2  \
# 5570523  2016-03-01    11605            NaN          NaN          NaN
# 5570524  2016-03-02    11605            NaN          NaN          NaN
# 5570525  2016-03-03    11605            NaN          NaN          NaN
# 5570526  2016-03-04    11605            NaN          NaN          NaN
# 5570527  2016-03-05    11606            NaN          NaN          NaN
# 5570528  2016-03-06    11606            NaN          NaN          NaN
# 5570529  2016-03-07    11606            NaN          NaN          NaN
# 5570530  2016-03-08    11606            NaN          NaN          NaN
# 5570531  2016-03-09    11606            NaN          NaN          NaN
# 5570532  2016-03-10    11606            NaN          NaN          NaN
# 5570533  2016-03-11    11606            NaN          NaN          NaN
# 5570534  2016-03-12    11607            NaN          NaN          NaN
# 5570535  2016-03-13    11607            NaN          NaN          NaN
# 5570536  2016-03-14    11607            NaN          NaN          NaN
# 5570537  2016-03-15    11607            NaN          NaN          NaN
# 5570538  2016-03-16    11607            NaN          NaN          NaN
# 5570539  2016-03-17    11607  StPatricksDay     Cultural          NaN
# 5570540  2016-03-18    11607            NaN          NaN          NaN
# 5570541  2016-03-19    11608            NaN          NaN          NaN
# 5570542  2016-03-20    11608            NaN          NaN          NaN
# 5570543  2016-03-21    11608            NaN          NaN          NaN
# 5570544  2016-03-22    11608            NaN          NaN          NaN
# 5570545  2016-03-23    11608            NaN          NaN          NaN
# 5570546  2016-03-24    11608      Purim End    Religious          NaN
# 5570547  2016-03-25    11608            NaN          NaN          NaN
# 5570548  2016-03-26    11609            NaN          NaN          NaN
# 5570549  2016-03-27    11609         Easter     Cultural          NaN
# 5570550  2016-03-28    11609            NaN          NaN          NaN
# 5570551  2016-03-29    11609            NaN          NaN          NaN
# 5570552  2016-03-30    11609            NaN          NaN          NaN
# 5570553  2016-03-31    11609            NaN          NaN          NaN
#
#         event_type_2  snap  sales
# 5570523          NaN     1    NaN
# 5570524          NaN     1    NaN
# 5570525          NaN     1    NaN
# 5570526          NaN     1    NaN
# 5570527          NaN     1    NaN
# 5570528          NaN     1    NaN
# 5570529          NaN     1    NaN
# 5570530          NaN     1    NaN
# 5570531          NaN     1    NaN
# 5570532          NaN     1    NaN
# 5570533          NaN     0    NaN
# 5570534          NaN     0    NaN
# 5570535          NaN     0    NaN
# 5570536          NaN     0    NaN
# 5570537          NaN     0    NaN
# 5570538          NaN     0    NaN
# 5570539          NaN     0    NaN
# 5570540          NaN     0    NaN
# 5570541          NaN     0    NaN
# 5570542          NaN     0    NaN
# 5570543          NaN     0    NaN
# 5570544          NaN     0    NaN
# 5570545          NaN     0    NaN
# 5570546          NaN     0    NaN
# 5570547          NaN     0    NaN
# 5570548          NaN     0    NaN
# 5570549          NaN     0    NaN
# 5570550          NaN     0    NaN
# 5570551          NaN     0    NaN
# 5570552          NaN     0    NaN
# 5570553          NaN     0    NaN

# %%
df_future = pd.merge(df_calsales_future,df_price,how='left',on=['week_id'])
df_future
# Out:
#              date  week_id event_name_1 event_type_1 event_name_2  \
# 0      2016-03-01    11605          NaN          NaN          NaN
# 1      2016-03-01    11605          NaN          NaN          NaN
# 2      2016-03-01    11605          NaN          NaN          NaN
# 3      2016-03-01    11605          NaN          NaN          NaN
# 4      2016-03-01    11605          NaN          NaN          NaN
# ...           ...      ...          ...          ...          ...
# 94514  2016-03-31    11609          NaN          NaN          NaN
# 94515  2016-03-31    11609          NaN          NaN          NaN
# 94516  2016-03-31    11609          NaN          NaN          NaN
# 94517  2016-03-31    11609          NaN          NaN          NaN
# 94518  2016-03-31    11609          NaN          NaN          NaN
#
#       event_type_2  snap  sales        item_id  price
# 0              NaN     1    NaN  HOBBIES_1_001   8.26
# 1              NaN     1    NaN  HOBBIES_1_002   3.97
# 2              NaN     1    NaN  HOBBIES_1_003   2.97
# 3              NaN     1    NaN  HOBBIES_1_004   4.64
# 4              NaN     1    NaN  HOBBIES_1_005   2.88
# ...            ...   ...    ...            ...    ...
# 94514          NaN     0    NaN    FOODS_3_823   2.88
# 94515          NaN     0    NaN    FOODS_3_824   2.48
# 94516          NaN     0    NaN    FOODS_3_825   3.98
# 94517          NaN     0    NaN    FOODS_3_826   1.28
# 94518          NaN     0    NaN    FOODS_3_827   1.00
#
# [94519 rows x 10 columns]

# %%
df_item_description = df_sales[df_sales['date']==	'2011-03-01']
df_item_description
# Out:
#             date        item_id    dept_id   cat_id  sales
# 0     2011-03-01  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 1     2011-03-01  HOBBIES_1_002  HOBBIES_1  HOBBIES      0
# 2     2011-03-01  HOBBIES_1_003  HOBBIES_1  HOBBIES      0
# 3     2011-03-01  HOBBIES_1_004  HOBBIES_1  HOBBIES      0
# 4     2011-03-01  HOBBIES_1_005  HOBBIES_1  HOBBIES      0
# ...          ...            ...        ...      ...    ...
# 3044  2011-03-01    FOODS_3_823    FOODS_3    FOODS      0
# 3045  2011-03-01    FOODS_3_824    FOODS_3    FOODS      0
# 3046  2011-03-01    FOODS_3_825    FOODS_3    FOODS      0
# 3047  2011-03-01    FOODS_3_826    FOODS_3    FOODS      0
# 3048  2011-03-01    FOODS_3_827    FOODS_3    FOODS      0
#
# [3049 rows x 5 columns]

# %%
df_future = pd.merge(df_future,df_item_description[['item_id','dept_id','cat_id']],how='left',on=['item_id'])
df_future
# Out:
#              date  week_id event_name_1 event_type_1 event_name_2  \
# 0      2016-03-01    11605          NaN          NaN          NaN
# 1      2016-03-01    11605          NaN          NaN          NaN
# 2      2016-03-01    11605          NaN          NaN          NaN
# 3      2016-03-01    11605          NaN          NaN          NaN
# 4      2016-03-01    11605          NaN          NaN          NaN
# ...           ...      ...          ...          ...          ...
# 94514  2016-03-31    11609          NaN          NaN          NaN
# 94515  2016-03-31    11609          NaN          NaN          NaN
# 94516  2016-03-31    11609          NaN          NaN          NaN
# 94517  2016-03-31    11609          NaN          NaN          NaN
# 94518  2016-03-31    11609          NaN          NaN          NaN
#
#       event_type_2  snap  sales        item_id  price    dept_id   cat_id
# 0              NaN     1    NaN  HOBBIES_1_001   8.26  HOBBIES_1  HOBBIES
# 1              NaN     1    NaN  HOBBIES_1_002   3.97  HOBBIES_1  HOBBIES
# 2              NaN     1    NaN  HOBBIES_1_003   2.97  HOBBIES_1  HOBBIES
# 3              NaN     1    NaN  HOBBIES_1_004   4.64  HOBBIES_1  HOBBIES
# 4              NaN     1    NaN  HOBBIES_1_005   2.88  HOBBIES_1  HOBBIES
# ...            ...   ...    ...            ...    ...        ...      ...
# 94514          NaN     0    NaN    FOODS_3_823   2.88    FOODS_3    FOODS
# 94515          NaN     0    NaN    FOODS_3_824   2.48    FOODS_3    FOODS
# 94516          NaN     0    NaN    FOODS_3_825   3.98    FOODS_3    FOODS
# 94517          NaN     0    NaN    FOODS_3_826   1.28    FOODS_3    FOODS
# 94518          NaN     0    NaN    FOODS_3_827   1.00    FOODS_3    FOODS
#
# [94519 rows x 12 columns]

# %%
df_future.isna().sum()
# Out:
# date                0
# week_id             0
# event_name_1    85372
# event_type_1    85372
# event_name_2    94519
# event_type_2    94519
# snap                0
# sales           94519
# item_id             0
# price               0
# dept_id             0
# cat_id              0
# dtype: int64

# %%
df_calsales_past
# Out:
#                date  week_id event_name_1 event_type_1 event_name_2  \
# 0        2011-03-01    11105          NaN          NaN          NaN
# 1        2011-03-01    11105          NaN          NaN          NaN
# 2        2011-03-01    11105          NaN          NaN          NaN
# 3        2011-03-01    11105          NaN          NaN          NaN
# 4        2011-03-01    11105          NaN          NaN          NaN
# ...             ...      ...          ...          ...          ...
# 5570518  2016-02-29    11605          NaN          NaN          NaN
# 5570519  2016-02-29    11605          NaN          NaN          NaN
# 5570520  2016-02-29    11605          NaN          NaN          NaN
# 5570521  2016-02-29    11605          NaN          NaN          NaN
# 5570522  2016-02-29    11605          NaN          NaN          NaN
#
#         event_type_2  snap        item_id    dept_id   cat_id  sales
# 0                NaN     1  HOBBIES_1_001  HOBBIES_1  HOBBIES    0.0
# 1                NaN     1  HOBBIES_1_002  HOBBIES_1  HOBBIES    0.0
# 2                NaN     1  HOBBIES_1_003  HOBBIES_1  HOBBIES    0.0
# 3                NaN     1  HOBBIES_1_004  HOBBIES_1  HOBBIES    0.0
# 4                NaN     1  HOBBIES_1_005  HOBBIES_1  HOBBIES    0.0
# ...              ...   ...            ...        ...      ...    ...
# 5570518          NaN     0    FOODS_3_823    FOODS_3    FOODS    2.0
# 5570519          NaN     0    FOODS_3_824    FOODS_3    FOODS    0.0
# 5570520          NaN     0    FOODS_3_825    FOODS_3    FOODS    0.0
# 5570521          NaN     0    FOODS_3_826    FOODS_3    FOODS    1.0
# 5570522          NaN     0    FOODS_3_827    FOODS_3    FOODS    1.0
#
# [5570523 rows x 11 columns]

# %%
df_past
# Out:
#              date  week_id event_name_1 event_type_1 event_name_2  \
# 0      2016-03-01    11605          NaN          NaN          NaN
# 1      2016-03-01    11605          NaN          NaN          NaN
# 2      2016-03-01    11605          NaN          NaN          NaN
# 3      2016-03-01    11605          NaN          NaN          NaN
# 4      2016-03-01    11605          NaN          NaN          NaN
# ...           ...      ...          ...          ...          ...
# 94514  2016-03-31    11609          NaN          NaN          NaN
# 94515  2016-03-31    11609          NaN          NaN          NaN
# 94516  2016-03-31    11609          NaN          NaN          NaN
# 94517  2016-03-31    11609          NaN          NaN          NaN
# 94518  2016-03-31    11609          NaN          NaN          NaN
#
#       event_type_2  snap  sales        item_id  price    dept_id   cat_id
# 0              NaN     1    NaN  HOBBIES_1_001   8.26  HOBBIES_1  HOBBIES
# 1              NaN     1    NaN  HOBBIES_1_002   3.97  HOBBIES_1  HOBBIES
# 2              NaN     1    NaN  HOBBIES_1_003   2.97  HOBBIES_1  HOBBIES
# 3              NaN     1    NaN  HOBBIES_1_004   4.64  HOBBIES_1  HOBBIES
# 4              NaN     1    NaN  HOBBIES_1_005   2.88  HOBBIES_1  HOBBIES
# ...            ...   ...    ...            ...    ...        ...      ...
# 94514          NaN     0    NaN    FOODS_3_823   2.88    FOODS_3    FOODS
# 94515          NaN     0    NaN    FOODS_3_824   2.48    FOODS_3    FOODS
# 94516          NaN     0    NaN    FOODS_3_825   3.98    FOODS_3    FOODS
# 94517          NaN     0    NaN    FOODS_3_826   1.28    FOODS_3    FOODS
# 94518          NaN     0    NaN    FOODS_3_827   1.00    FOODS_3    FOODS
#
# [94519 rows x 12 columns]

# %%
df_past = pd.merge(df_calsales_past,df_price,how='left',on=['week_id','item_id'])
df_past
# Out:
#                date  week_id event_name_1 event_type_1 event_name_2  \
# 0        2011-03-01    11105          NaN          NaN          NaN
# 1        2011-03-01    11105          NaN          NaN          NaN
# 2        2011-03-01    11105          NaN          NaN          NaN
# 3        2011-03-01    11105          NaN          NaN          NaN
# 4        2011-03-01    11105          NaN          NaN          NaN
# ...             ...      ...          ...          ...          ...
# 5570518  2016-02-29    11605          NaN          NaN          NaN
# 5570519  2016-02-29    11605          NaN          NaN          NaN
# 5570520  2016-02-29    11605          NaN          NaN          NaN
# 5570521  2016-02-29    11605          NaN          NaN          NaN
# 5570522  2016-02-29    11605          NaN          NaN          NaN
#
#         event_type_2  snap        item_id    dept_id   cat_id  sales  price
# 0                NaN     1  HOBBIES_1_001  HOBBIES_1  HOBBIES    0.0    NaN
# 1                NaN     1  HOBBIES_1_002  HOBBIES_1  HOBBIES    0.0    NaN
# 2                NaN     1  HOBBIES_1_003  HOBBIES_1  HOBBIES    0.0    NaN
# 3                NaN     1  HOBBIES_1_004  HOBBIES_1  HOBBIES    0.0    NaN
# 4                NaN     1  HOBBIES_1_005  HOBBIES_1  HOBBIES    0.0    NaN
# ...              ...   ...            ...        ...      ...    ...    ...
# 5570518          NaN     0    FOODS_3_823    FOODS_3    FOODS    2.0   2.88
# 5570519          NaN     0    FOODS_3_824    FOODS_3    FOODS    0.0   2.68
# 5570520          NaN     0    FOODS_3_825    FOODS_3    FOODS    0.0   3.98
# 5570521          NaN     0    FOODS_3_826    FOODS_3    FOODS    1.0   1.28
# 5570522          NaN     0    FOODS_3_827    FOODS_3    FOODS    1.0   1.00
#
# [5570523 rows x 12 columns]

# %%
list_df = [df_past,df_future]
df = pd.concat(list_df)
df = df.reset_index(drop=True)
df
# Out:
#                date  week_id event_name_1 event_type_1 event_name_2  \
# 0        2011-03-01    11105          NaN          NaN          NaN
# 1        2011-03-01    11105          NaN          NaN          NaN
# 2        2011-03-01    11105          NaN          NaN          NaN
# 3        2011-03-01    11105          NaN          NaN          NaN
# 4        2011-03-01    11105          NaN          NaN          NaN
# ...             ...      ...          ...          ...          ...
# 5665037  2016-03-31    11609          NaN          NaN          NaN
# 5665038  2016-03-31    11609          NaN          NaN          NaN
# 5665039  2016-03-31    11609          NaN          NaN          NaN
# 5665040  2016-03-31    11609          NaN          NaN          NaN
# 5665041  2016-03-31    11609          NaN          NaN          NaN
#
#         event_type_2  snap        item_id    dept_id   cat_id  sales  price
# 0                NaN     1  HOBBIES_1_001  HOBBIES_1  HOBBIES    0.0    NaN
# 1                NaN     1  HOBBIES_1_002  HOBBIES_1  HOBBIES    0.0    NaN
# 2                NaN     1  HOBBIES_1_003  HOBBIES_1  HOBBIES    0.0    NaN
# 3                NaN     1  HOBBIES_1_004  HOBBIES_1  HOBBIES    0.0    NaN
# 4                NaN     1  HOBBIES_1_005  HOBBIES_1  HOBBIES    0.0    NaN
# ...              ...   ...            ...        ...      ...    ...    ...
# 5665037          NaN     0    FOODS_3_823    FOODS_3    FOODS    NaN   2.88
# 5665038          NaN     0    FOODS_3_824    FOODS_3    FOODS    NaN   2.48
# 5665039          NaN     0    FOODS_3_825    FOODS_3    FOODS    NaN   3.98
# 5665040          NaN     0    FOODS_3_826    FOODS_3    FOODS    NaN   1.28
# 5665041          NaN     0    FOODS_3_827    FOODS_3    FOODS    NaN   1.00
#
# [5665042 rows x 12 columns]

# %% [markdown]
# Testen auf Robustheit des Merger

# %%
df[(df['item_id']=='HOBBIES_1_010')&(df['week_id']==11105)]
# Out:
#             date  week_id event_name_1 event_type_1 event_name_2 event_type_2  \
# 9     2011-03-01    11105          NaN          NaN          NaN          NaN
# 3058  2011-03-02    11105          NaN          NaN          NaN          NaN
# 6107  2011-03-03    11105          NaN          NaN          NaN          NaN
# 9156  2011-03-04    11105          NaN          NaN          NaN          NaN
#
#       snap        item_id    dept_id   cat_id  sales  price
# 9        1  HOBBIES_1_010  HOBBIES_1  HOBBIES    0.0   3.17
# 3058     1  HOBBIES_1_010  HOBBIES_1  HOBBIES    0.0   3.17
# 6107     1  HOBBIES_1_010  HOBBIES_1  HOBBIES    0.0   3.17
# 9156     1  HOBBIES_1_010  HOBBIES_1  HOBBIES    0.0   3.17

# %%
df_price[df_price['week_id']==11105]
# Out:
#               item_id  week_id  price
# 1428    HOBBIES_1_008    11105   0.42
# 1694    HOBBIES_1_009    11105   1.56
# 1960    HOBBIES_1_010    11105   3.17
# 2432    HOBBIES_1_012    11105   5.98
# 3134    HOBBIES_1_015    11105   0.72
# ...               ...      ...    ...
# 654659    FOODS_3_819    11105   1.98
# 654925    FOODS_3_820    11105   1.57
# 655348    FOODS_3_822    11105   4.28
# 655805    FOODS_3_824    11105   2.48
# 656071    FOODS_3_825    11105   4.00
#
# [1413 rows x 3 columns]

# %%
df_price[(df_price['week_id']==11105) & (df_price['item_id']=='HOBBIES_1_010')]
# Out:
#             item_id  week_id  price
# 1960  HOBBIES_1_010    11105   3.17

# %% [markdown]
# Vergleich Preiswerte aus df_price mit gemergetem Dataframe

# %%
df_sales[(df_sales['date']>='2011-03-01')&(df_sales['date']<='2011-03-21')&(df_sales['item_id']=='HOBBIES_1_001')]
# Out:
#              date        item_id    dept_id   cat_id  sales
# 0      2011-03-01  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 3049   2011-03-02  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 6098   2011-03-03  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 9147   2011-03-04  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 12196  2011-03-05  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 15245  2011-03-06  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 18294  2011-03-07  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 21343  2011-03-08  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 24392  2011-03-09  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 27441  2011-03-10  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 30490  2011-03-11  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 33539  2011-03-12  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 36588  2011-03-13  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 39637  2011-03-14  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 42686  2011-03-15  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 45735  2011-03-16  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 48784  2011-03-17  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 51833  2011-03-18  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 54882  2011-03-19  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 57931  2011-03-20  HOBBIES_1_001  HOBBIES_1  HOBBIES      0
# 60980  2011-03-21  HOBBIES_1_001  HOBBIES_1  HOBBIES      0

# %% [markdown]
# Vergleich Saleswerte aus df_sales mit gemergetem Dataframe

# %%
df.dtypes
# Out:
# date             object
# week_id           int64
# event_name_1     object
# event_type_1     object
# event_name_2     object
# event_type_2     object
# snap              int64
# item_id          object
# dept_id          object
# cat_id           object
# sales           float64
# price           float64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# date            datetime64[ns]
# week_id                  int64
# event_name_1            object
# event_type_1            object
# event_name_2            object
# event_type_2            object
# snap                     int64
# item_id                 object
# dept_id                 object
# cat_id                  object
# sales                  float64
# price                  float64
# dtype: object

# %% [markdown]
# Um mit dem Datum rechnen zu können ändern wir den Datentyp von Objekt zu einem datetime-objekt.

# %% [markdown]
# ### 3)Datenbereinigung

# %%
df[(df['date']=='2011-05-23')&(df['item_id']=='HOBBIES_1_010')]
# Out:
#              date  week_id event_name_1 event_type_1 event_name_2  \
# 253076 2011-05-23    11117          NaN          NaN          NaN
#
#        event_type_2  snap        item_id    dept_id   cat_id  sales  price
# 253076          NaN     0  HOBBIES_1_010  HOBBIES_1  HOBBIES    3.0   2.97

# %% [markdown]
# NaN

# %%
df[df['sales'].isnull()==True]
# Out:
#               date  week_id event_name_1 event_type_1 event_name_2  \
# 5570523 2016-03-01    11605          NaN          NaN          NaN
# 5570524 2016-03-01    11605          NaN          NaN          NaN
# 5570525 2016-03-01    11605          NaN          NaN          NaN
# 5570526 2016-03-01    11605          NaN          NaN          NaN
# 5570527 2016-03-01    11605          NaN          NaN          NaN
# ...            ...      ...          ...          ...          ...
# 5665037 2016-03-31    11609          NaN          NaN          NaN
# 5665038 2016-03-31    11609          NaN          NaN          NaN
# 5665039 2016-03-31    11609          NaN          NaN          NaN
# 5665040 2016-03-31    11609          NaN          NaN          NaN
# 5665041 2016-03-31    11609          NaN          NaN          NaN
#
#         event_type_2  snap        item_id    dept_id   cat_id  sales  price
# 5570523          NaN     1  HOBBIES_1_001  HOBBIES_1  HOBBIES    NaN   8.26
# 5570524          NaN     1  HOBBIES_1_002  HOBBIES_1  HOBBIES    NaN   3.97
# 5570525          NaN     1  HOBBIES_1_003  HOBBIES_1  HOBBIES    NaN   2.97
# 5570526          NaN     1  HOBBIES_1_004  HOBBIES_1  HOBBIES    NaN   4.64
# 5570527          NaN     1  HOBBIES_1_005  HOBBIES_1  HOBBIES    NaN   2.88
# ...              ...   ...            ...        ...      ...    ...    ...
# 5665037          NaN     0    FOODS_3_823    FOODS_3    FOODS    NaN   2.88
# 5665038          NaN     0    FOODS_3_824    FOODS_3    FOODS    NaN   2.48
# 5665039          NaN     0    FOODS_3_825    FOODS_3    FOODS    NaN   3.98
# 5665040          NaN     0    FOODS_3_826    FOODS_3    FOODS    NaN   1.28
# 5665041          NaN     0    FOODS_3_827    FOODS_3    FOODS    NaN   1.00
#
# [94519 rows x 12 columns]

# %% [markdown]
# NaN in Sales nur ab dem 01.03.2016 da ab dort keine Sales Daten mehr verfügbar sind, der Kalendar jedoch bis zum 31.03.2016 geht.

# %%
df[df['price'].isnull()==True]
# Out:
#               date  week_id event_name_1 event_type_1 event_name_2  \
# 0       2011-03-01    11105          NaN          NaN          NaN
# 1       2011-03-01    11105          NaN          NaN          NaN
# 2       2011-03-01    11105          NaN          NaN          NaN
# 3       2011-03-01    11105          NaN          NaN          NaN
# 4       2011-03-01    11105          NaN          NaN          NaN
# ...            ...      ...          ...          ...          ...
# 5506264 2016-02-08    11602          NaN          NaN          NaN
# 5509313 2016-02-09    11602          NaN          NaN          NaN
# 5512362 2016-02-10    11602    LentStart    Religious          NaN
# 5515411 2016-02-11    11602          NaN          NaN          NaN
# 5518460 2016-02-12    11602          NaN          NaN          NaN
#
#         event_type_2  snap        item_id    dept_id   cat_id  sales  price
# 0                NaN     1  HOBBIES_1_001  HOBBIES_1  HOBBIES    0.0    NaN
# 1                NaN     1  HOBBIES_1_002  HOBBIES_1  HOBBIES    0.0    NaN
# 2                NaN     1  HOBBIES_1_003  HOBBIES_1  HOBBIES    0.0    NaN
# 3                NaN     1  HOBBIES_1_004  HOBBIES_1  HOBBIES    0.0    NaN
# 4                NaN     1  HOBBIES_1_005  HOBBIES_1  HOBBIES    0.0    NaN
# ...              ...   ...            ...        ...      ...    ...    ...
# 5506264          NaN     1    FOODS_3_595    FOODS_3    FOODS    0.0    NaN
# 5509313          NaN     1    FOODS_3_595    FOODS_3    FOODS    0.0    NaN
# 5512362          NaN     1    FOODS_3_595    FOODS_3    FOODS    0.0    NaN
# 5515411          NaN     0    FOODS_3_595    FOODS_3    FOODS    0.0    NaN
# 5518460          NaN     0    FOODS_3_595    FOODS_3    FOODS    0.0    NaN
#
# [1076480 rows x 12 columns]

# %%
df[(df['price'].isnull()==True)&(df['sales']>0)]
# Out:
# Empty DataFrame
# Columns: [date, week_id, event_name_1, event_type_1, event_name_2, event_type_2, snap, item_id, dept_id, cat_id, sales, price]
# Index: []

# %% [markdown]
# Price ist nur NaN wenn Sales auch 0 ist. Wahrscheinlich wenn das Produkt noch nicht verkauft wurde.

# %%
df
# Out:
#               date  week_id event_name_1 event_type_1 event_name_2  \
# 0       2011-03-01    11105          NaN          NaN          NaN
# 1       2011-03-01    11105          NaN          NaN          NaN
# 2       2011-03-01    11105          NaN          NaN          NaN
# 3       2011-03-01    11105          NaN          NaN          NaN
# 4       2011-03-01    11105          NaN          NaN          NaN
# ...            ...      ...          ...          ...          ...
# 5665037 2016-03-31    11609          NaN          NaN          NaN
# 5665038 2016-03-31    11609          NaN          NaN          NaN
# 5665039 2016-03-31    11609          NaN          NaN          NaN
# 5665040 2016-03-31    11609          NaN          NaN          NaN
# 5665041 2016-03-31    11609          NaN          NaN          NaN
#
#         event_type_2  snap        item_id    dept_id   cat_id  sales  price
# 0                NaN     1  HOBBIES_1_001  HOBBIES_1  HOBBIES    0.0    NaN
# 1                NaN     1  HOBBIES_1_002  HOBBIES_1  HOBBIES    0.0    NaN
# 2                NaN     1  HOBBIES_1_003  HOBBIES_1  HOBBIES    0.0    NaN
# 3                NaN     1  HOBBIES_1_004  HOBBIES_1  HOBBIES    0.0    NaN
# 4                NaN     1  HOBBIES_1_005  HOBBIES_1  HOBBIES    0.0    NaN
# ...              ...   ...            ...        ...      ...    ...    ...
# 5665037          NaN     0    FOODS_3_823    FOODS_3    FOODS    NaN   2.88
# 5665038          NaN     0    FOODS_3_824    FOODS_3    FOODS    NaN   2.48
# 5665039          NaN     0    FOODS_3_825    FOODS_3    FOODS    NaN   3.98
# 5665040          NaN     0    FOODS_3_826    FOODS_3    FOODS    NaN   1.28
# 5665041          NaN     0    FOODS_3_827    FOODS_3    FOODS    NaN   1.00
#
# [5665042 rows x 12 columns]

# %%
df_plot = df[['week_id', 'sales', 'price']].groupby(by='week_id').agg({'sales': 'sum', 'price': 'mean'})
#df_plot.reset_index(inplace=True)
df_plot
# Out:
#            sales     price
# week_id
# 11105    10654.0  4.167098
# 11106    23734.0  4.157467
# 11107    21173.0  4.186751
# 11108    20239.0  4.182711
# 11109    21168.0  4.192611
# ...          ...       ...
# 11605    15324.0  4.492801
# 11606        0.0  4.490062
# 11607        0.0  4.489774
# 11608        0.0  4.490128
# 11609        0.0  4.489718
#
# [266 rows x 2 columns]

# %%
sns.lineplot(x=df_plot.index, y='sales', data=df_plot)
# Out:
# <AxesSubplot: xlabel='week_id', ylabel='sales'>

# %% [markdown]
# Wenn wir anhand der Week_id gruppieren fehlen uns Zeiträume

# %%
df_plot.loc['11150':'11200']
# Out:
#            sales     price
# week_id
# 11150    25308.0  4.254329
# 11151    23540.0  4.261167
# 11152    22905.0  4.262562

# %%
df_cal[df_cal['week_id']== 11151]
# Out:
#            date  week_id         event_name_1 event_type_1 event_name_2  \
# 319  2012-01-14    11151                  NaN          NaN          NaN
# 320  2012-01-15    11151                  NaN          NaN          NaN
# 321  2012-01-16    11151  MartinLutherKingDay     National          NaN
# 322  2012-01-17    11151                  NaN          NaN          NaN
# 323  2012-01-18    11151                  NaN          NaN          NaN
# 324  2012-01-19    11151                  NaN          NaN          NaN
# 325  2012-01-20    11151                  NaN          NaN          NaN
#
#     event_type_2  snap
# 319          NaN     0
# 320          NaN     0
# 321          NaN     0
# 322          NaN     0
# 323          NaN     0
# 324          NaN     0
# 325          NaN     0

# %% [markdown]
# Week_id endet immer in der Endung 52 und springt dann zum nächsten Hunderter. Daher erstellen wir eine eigene Spalte mit der KW/Jahr.

# %%
df.head()
# Out:
#         date  week_id event_name_1 event_type_1 event_name_2 event_type_2  \
# 0 2011-03-01    11105          NaN          NaN          NaN          NaN
# 1 2011-03-01    11105          NaN          NaN          NaN          NaN
# 2 2011-03-01    11105          NaN          NaN          NaN          NaN
# 3 2011-03-01    11105          NaN          NaN          NaN          NaN
# 4 2011-03-01    11105          NaN          NaN          NaN          NaN
#
#    snap        item_id    dept_id   cat_id  sales  price
# 0     1  HOBBIES_1_001  HOBBIES_1  HOBBIES    0.0    NaN
# 1     1  HOBBIES_1_002  HOBBIES_1  HOBBIES    0.0    NaN
# 2     1  HOBBIES_1_003  HOBBIES_1  HOBBIES    0.0    NaN
# 3     1  HOBBIES_1_004  HOBBIES_1  HOBBIES    0.0    NaN
# 4     1  HOBBIES_1_005  HOBBIES_1  HOBBIES    0.0    NaN

# %%
import datetime
df['yearcw'] = df['date'].dt.year.astype('str') + df['date'].dt.strftime('%W')

# %%
df
# Out:
#               date  week_id event_name_1 event_type_1 event_name_2  \
# 0       2011-03-01    11105          NaN          NaN          NaN
# 1       2011-03-01    11105          NaN          NaN          NaN
# 2       2011-03-01    11105          NaN          NaN          NaN
# 3       2011-03-01    11105          NaN          NaN          NaN
# 4       2011-03-01    11105          NaN          NaN          NaN
# ...            ...      ...          ...          ...          ...
# 5665037 2016-03-31    11609          NaN          NaN          NaN
# 5665038 2016-03-31    11609          NaN          NaN          NaN
# 5665039 2016-03-31    11609          NaN          NaN          NaN
# 5665040 2016-03-31    11609          NaN          NaN          NaN
# 5665041 2016-03-31    11609          NaN          NaN          NaN
#
#         event_type_2  snap        item_id    dept_id   cat_id  sales  price  \
# 0                NaN     1  HOBBIES_1_001  HOBBIES_1  HOBBIES    0.0    NaN
# 1                NaN     1  HOBBIES_1_002  HOBBIES_1  HOBBIES    0.0    NaN
# 2                NaN     1  HOBBIES_1_003  HOBBIES_1  HOBBIES    0.0    NaN
# 3                NaN     1  HOBBIES_1_004  HOBBIES_1  HOBBIES    0.0    NaN
# 4                NaN     1  HOBBIES_1_005  HOBBIES_1  HOBBIES    0.0    NaN
# ...              ...   ...            ...        ...      ...    ...    ...
# 5665037          NaN     0    FOODS_3_823    FOODS_3    FOODS    NaN   2.88
# 5665038          NaN     0    FOODS_3_824    FOODS_3    FOODS    NaN   2.48
# 5665039          NaN     0    FOODS_3_825    FOODS_3    FOODS    NaN   3.98
# 5665040          NaN     0    FOODS_3_826    FOODS_3    FOODS    NaN   1.28
# 5665041          NaN     0    FOODS_3_827    FOODS_3    FOODS    NaN   1.00
#
#          yearcw
# 0        201109
# 1        201109
# 2        201109
# 3        201109
# 4        201109
# ...         ...
# 5665037  201613
# 5665038  201613
# 5665039  201613
# 5665040  201613
# 5665041  201613
#
# [5665042 rows x 13 columns]

# %%
df_plot2 = df[['yearcw', 'sales', 'price']].groupby(by='yearcw').agg({'sales': 'sum', 'price': 'mean'})
#df_plot.reset_index(inplace=True)
df_plot2
# Out:
#           sales     price
# yearcw
# 201109  19582.0  4.163840
# 201110  23014.0  4.165941
# 201111  21011.0  4.185586
# 201112  20091.0  4.185566
# 201113  21991.0  4.195129
# ...         ...       ...
# 201609   3797.0  4.492018
# 201610      0.0  4.489980
# 201611      0.0  4.489875
# 201612      0.0  4.490011
# 201613      0.0  4.489718
#
# [271 rows x 2 columns]

# %%
sns.lineplot(x=df_plot2.index, y='sales', data=df_plot2)
# Out:
# <AxesSubplot: xlabel='yearcw', ylabel='sales'>

# %%
df[df['yearcw']=='201352']
# Out:
#               date  week_id event_name_1 event_type_1 event_name_2  \
# 3155715 2013-12-30    11349          NaN          NaN          NaN
# 3155716 2013-12-30    11349          NaN          NaN          NaN
# 3155717 2013-12-30    11349          NaN          NaN          NaN
# 3155718 2013-12-30    11349          NaN          NaN          NaN
# 3155719 2013-12-30    11349          NaN          NaN          NaN
# ...            ...      ...          ...          ...          ...
# 3161808 2013-12-31    11349          NaN          NaN          NaN
# 3161809 2013-12-31    11349          NaN          NaN          NaN
# 3161810 2013-12-31    11349          NaN          NaN          NaN
# 3161811 2013-12-31    11349          NaN          NaN          NaN
# 3161812 2013-12-31    11349          NaN          NaN          NaN
#
#         event_type_2  snap        item_id    dept_id   cat_id  sales  price  \
# 3155715          NaN     0  HOBBIES_1_001  HOBBIES_1  HOBBIES    0.0   8.26
# 3155716          NaN     0  HOBBIES_1_002  HOBBIES_1  HOBBIES    0.0   3.97
# 3155717          NaN     0  HOBBIES_1_003  HOBBIES_1  HOBBIES    0.0    NaN
# 3155718          NaN     0  HOBBIES_1_004  HOBBIES_1  HOBBIES    1.0   4.64
# 3155719          NaN     0  HOBBIES_1_005  HOBBIES_1  HOBBIES    0.0   3.08
# ...              ...   ...            ...        ...      ...    ...    ...
# 3161808          NaN     0    FOODS_3_823    FOODS_3    FOODS    2.0   2.50
# 3161809          NaN     0    FOODS_3_824    FOODS_3    FOODS    0.0   2.68
# 3161810          NaN     0    FOODS_3_825    FOODS_3    FOODS    0.0   3.98
# 3161811          NaN     0    FOODS_3_826    FOODS_3    FOODS    0.0   1.28
# 3161812          NaN     0    FOODS_3_827    FOODS_3    FOODS    0.0    NaN
#
#          yearcw
# 3155715  201352
# 3155716  201352
# 3155717  201352
# 3155718  201352
# 3155719  201352
# ...         ...
# 3161808  201352
# 3161809  201352
# 3161810  201352
# 3161811  201352
# 3161812  201352
#
# [6098 rows x 13 columns]

# %%
df_plot2.iloc[145:155]
# Out:
#           sales     price
# yearcw
# 201347  25970.0  4.395055
# 201348  32355.0  4.394091
# 201349  29655.0  4.394340
# 201350  29338.0  4.393391
# 201351  24772.0  4.391828
# 201352   8469.0  4.388859
# 201400  22585.0  4.391800
# 201401  30163.0  4.398940
# 201402  27802.0  4.407356
# 201403  27096.0  4.411399

# %% [markdown]
# Anhand der Datumswerte

# %%
df_plot3 = df[['date', 'sales', 'price']].groupby(by='date').agg({'sales': 'sum', 'price': 'mean'})
#df_plot.reset_index(inplace=True)
df_plot3
# Out:
#              sales     price
# date
# 2011-03-01  2549.0  4.167098
# 2011-03-02  2559.0  4.167098
# 2011-03-03  2568.0  4.167098
# 2011-03-04  2978.0  4.167098
# 2011-03-05  4096.0  4.157467
# ...            ...       ...
# 2016-03-27     0.0  4.489718
# 2016-03-28     0.0  4.489718
# 2016-03-29     0.0  4.489718
# 2016-03-30     0.0  4.489718
# 2016-03-31     0.0  4.489718
#
# [1858 rows x 2 columns]

# %%
sns.lineplot(x=df_plot3.index, y='sales', data=df_plot3)
# Out:
# <AxesSubplot: xlabel='date', ylabel='sales'>

# %%
df_plot3.iloc[290:310]
# Out:
#              sales     price
# date
# 2011-12-16  3399.0  4.268003
# 2011-12-17  4463.0  4.274261
# 2011-12-18  4253.0  4.274261
# 2011-12-19  3333.0  4.274261
# 2011-12-20  3236.0  4.274261
# 2011-12-21  3367.0  4.274261
# 2011-12-22  3609.0  4.274261
# 2011-12-23  4652.0  4.274261
# 2011-12-24  3454.0  4.275740
# 2011-12-25     0.0  4.275740
# 2011-12-26  3335.0  4.275740
# 2011-12-27  3111.0  4.275740
# 2011-12-28  3097.0  4.275740
# 2011-12-29  3233.0  4.275740
# 2011-12-30  4638.0  4.275740
# 2011-12-31  4236.0  4.264503
# 2012-01-01  2648.0  4.264503
# 2012-01-02  3931.0  4.264503
# 2012-01-03  3496.0  4.264503
# 2012-01-04  3284.0  4.264503

# %%
sns.stripplot(
    data=df_plot3,
    y='sales'
)
# Out:
# <AxesSubplot: ylabel='sales'>

# %% [markdown]
# Im Schnitt befinden sich unsere täglichen Sales zwischen 3000 und 5000

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=False)
#fig.suptitle('')

sns.boxplot(data=df_plot3, x='sales', showmeans=True, showfliers=False, ax=axes[0])
axes[0].set_title('sales per day')

sns.boxplot(data=df_plot3, x='price', showmeans=True, showfliers=False, ax=axes[1])
axes[1].set_title('Avg Price per day')
# Out:
# Text(0.5, 1.0, 'Avg Price per day')

# %%
df_plot4 = df[['date', 'sales']].groupby(by='date').sum()
df_plot4.reset_index(inplace=True)
df_plot4['year'] = df_plot4['date'].dt.year
df_plot4['month'] = df_plot4['date'].dt.month

plot = sns.lineplot(
    data=df_plot4,
    x='month',
    y='sales',
    hue='year',
    estimator=sum,
    ci=None,
    palette='deep'
).set(title='Sales per Month')
# Out:
# C:\Users\Dave\AppData\Local\Temp\ipykernel_29508\98930927.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   plot = sns.lineplot(

# %%
df
# Out:
#               date  week_id event_name_1 event_type_1 event_name_2  \
# 0       2011-03-01    11105          NaN          NaN          NaN
# 1       2011-03-01    11105          NaN          NaN          NaN
# 2       2011-03-01    11105          NaN          NaN          NaN
# 3       2011-03-01    11105          NaN          NaN          NaN
# 4       2011-03-01    11105          NaN          NaN          NaN
# ...            ...      ...          ...          ...          ...
# 5570549 2016-03-27    11609       Easter     Cultural          NaN
# 5570550 2016-03-28    11609          NaN          NaN          NaN
# 5570551 2016-03-29    11609          NaN          NaN          NaN
# 5570552 2016-03-30    11609          NaN          NaN          NaN
# 5570553 2016-03-31    11609          NaN          NaN          NaN
#
#         event_type_2  snap        item_id    dept_id   cat_id  sales  price  \
# 0                NaN     1  HOBBIES_1_001  HOBBIES_1  HOBBIES    0.0    0.0
# 1                NaN     1  HOBBIES_1_002  HOBBIES_1  HOBBIES    0.0    0.0
# 2                NaN     1  HOBBIES_1_003  HOBBIES_1  HOBBIES    0.0    0.0
# 3                NaN     1  HOBBIES_1_004  HOBBIES_1  HOBBIES    0.0    0.0
# 4                NaN     1  HOBBIES_1_005  HOBBIES_1  HOBBIES    0.0    0.0
# ...              ...   ...            ...        ...      ...    ...    ...
# 5570549          NaN     0            NaN        NaN      NaN    NaN    NaN
# 5570550          NaN     0            NaN        NaN      NaN    NaN    NaN
# 5570551          NaN     0            NaN        NaN      NaN    NaN    NaN
# 5570552          NaN     0            NaN        NaN      NaN    NaN    NaN
# 5570553          NaN     0            NaN        NaN      NaN    NaN    NaN
#
#          yearcw
# 0        201109
# 1        201109
# 2        201109
# 3        201109
# 4        201109
# ...         ...
# 5570549  201612
# 5570550  201613
# 5570551  201613
# 5570552  201613
# 5570553  201613
#
# [5570554 rows x 13 columns]

# %%
df_plot5 = df[['date', 'sales']].groupby(by='date').sum()
g = sns.lineplot(data = df_plot5)

# %%
df_plot5
# Out:
#              sales
# date
# 2011-03-01  2549.0
# 2011-03-02  2559.0
# 2011-03-03  2568.0
# 2011-03-04  2978.0
# 2011-03-05  4096.0
# ...            ...
# 2016-03-27     0.0
# 2016-03-28     0.0
# 2016-03-29     0.0
# 2016-03-30     0.0
# 2016-03-31     0.0
#
# [1858 rows x 1 columns]

# %%
data = df_plot5.loc['2014-06-15':'2014-06-30']
g = sns.lineplot(data = data)

# %% [markdown]
# Wir sehen in den Sales Daten einen starken 7-tägigen saisonalen Verlauf. Bis Donnerstags sinken die Sales stark und steigen bis Sonntag an.
# Deshalb rechnen wir den 7tägigen Trend raus.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decompose = seasonal_decompose(
    x=df_plot5,
    period=7
)

decompose.plot()
plt.show()

# %% [markdown]
# Zur Prüfung vergleichen wir das Ergebnis mit einem 14tägigen saisonalen Effekt.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decompose2 = seasonal_decompose(
    x=df_plot5,
    period=14
)

decompose2.plot()
plt.show()

# %% [markdown]
# Hier sehen wir jedoch keine signifikanten Änderungen im Trend.

# %%
data = decompose.trend.loc['2014-06-01':'2014-06-30']
g1 = sns.lineplot(data = data)

data = df_plot5.loc['2014-06-01':'2014-06-30']
g2 = sns.lineplot(data = data, ax=g1)

# %% [markdown]
# Wenn wir uns den Trend ohne die 7tägige Saisonalität anschauen sehen wir keine auffälligen Saisonalitäten mehr.

# %%
data = decompose.seasonal.loc['2013-01-01':'2013-01-14']
g = sns.lineplot(data = data)

# %%
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf

data = df_plot5

plot_acf(data, zero = False)
plt.show()
plot_pacf(data, zero = False)
plt.show()
# Out:
# c:\Users\Dave\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# ACF - Der selbe Tag in der Vorwoche hat einen starken Einfluss auf die Sales Zahlen über die Woche. D.h. wenn der Sonntag sehr gut läuft werden die anderen Tage aus eher gut laufen aber nur so gut wie die einzelnen Tage normalerweiser immer laufen. D.h. ein guter Sonntag führt auch zu einem guten Mittwoch der aber natürlich weniger Sales hat als der Sonntag.
# PACF - Der letzte Tag hat einen starken direkten Einfluss auf das Ergebnis des Folgetages. Die Performance der Vorwoche hat einen starken Einfluss auf das Ergebnis des untersuchten Tages, die Woche davor wieder weniger usw.

# %%
df.to_pickle('df.pickle')
